# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the datasets
df1 = pd.read_csv('/content/fertility_woman.csv',skiprows=4)
df2  = pd.read_csv('/content/gdp_per_capita.csv',skiprows=4)

# %%
# checking the structure
df1.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                              Indicator Name  Indicator Code      1960  \
# 0  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  4.820000
# 1  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.724125
# 2  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  7.282000
# 3  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.458448
# 4  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.708000
#
#        1961      1962      1963      1964      1965  ...      2015      2016  \
# 0  4.655000  4.471000  4.271000  4.059000  3.842000  ...  1.972000  1.953000
# 1  6.742752  6.762930  6.778712  6.788420  6.800322  ...  4.677618  4.615670
# 2  7.284000  7.292000  7.302000  7.304000  7.305000  ...  5.405000  5.262000
# 3  6.471518  6.491826  6.506088  6.525355  6.541102  ...  5.385059  5.328709
# 4  6.790000  6.872000  6.954000  7.036000  7.116000  ...  5.774000  5.686000
#
#        2017      2018      2019      2020      2021      2022  2023  \
# 0  1.839000  1.587000  1.486000  1.325000  1.180000  1.179000   NaN
# 1  4.570409  4.527705  4.482898  4.416900  4.354709  4.288788   NaN
# 2  5.129000  5.002000  4.870000  4.750000  4.643000  4.523000   NaN
# 3  5.255345  5.186319  5.118932  5.049329  4.978662  4.897322   NaN
# 4  5.600000  5.519000  5.442000  5.371000  5.304000  5.209000   NaN
#
#    Unnamed: 68
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 69 columns]

# %%
df2.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                   Indicator Name     Indicator Code  1960  \
# 0  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 1  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 2  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 3  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 4  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2015          2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  37231.918495  37444.441094
# 1   NaN   NaN   NaN   NaN   NaN  ...   3502.296662   3595.841041
# 2   NaN   NaN   NaN   NaN   NaN  ...   2289.371986   2217.296786
# 3   NaN   NaN   NaN   NaN   NaN  ...   4130.736274   4072.792261
# 4   NaN   NaN   NaN   NaN   NaN  ...   7127.339573   6850.384625
#
#            2017          2018          2019          2020          2021  \
# 0  38697.949507  40379.293724  40124.757998  30437.202516  38226.146157
# 1   3640.628582   3695.386884   3783.518751   3666.871961   3967.400629
# 2   2338.778697   2436.006320   2589.410396   2568.341909   2138.870247
# 3   4139.387604   4272.387852   4525.091244   4503.396648   4756.308419
# 4   6998.796187   7353.349988   7533.511854   6455.119982   7414.278958
#
#            2022         2023  Unnamed: 68
# 0  45236.021214          NaN          NaN
# 1   4294.025281  4459.764134          NaN
# 2   2092.879952          NaN          NaN
# 3   5156.120103  5389.580896          NaN
# 4   7928.641498  8040.543601          NaN
#
# [5 rows x 69 columns]

# %%
df1.tail()
# Out:
#      Country Name Country Code                            Indicator Name  \
# 261        Kosovo          XKX  Fertility rate, total (births per woman)
# 262   Yemen, Rep.          YEM  Fertility rate, total (births per woman)
# 263  South Africa          ZAF  Fertility rate, total (births per woman)
# 264        Zambia          ZMB  Fertility rate, total (births per woman)
# 265      Zimbabwe          ZWE  Fertility rate, total (births per woman)
#
#      Indicator Code   1960   1961   1962   1963   1964   1965  ...   2015  \
# 261  SP.DYN.TFRT.IN  6.359  6.350  6.331  6.296  6.126  5.927  ...  1.751
# 262  SP.DYN.TFRT.IN  7.938  7.963  7.963  7.981  8.038  8.067  ...  4.322
# 263  SP.DYN.TFRT.IN  6.159  6.138  6.110  6.077  6.030  5.967  ...  2.359
# 264  SP.DYN.TFRT.IN  7.115  7.169  7.214  7.249  7.274  7.291  ...  4.793
# 265  SP.DYN.TFRT.IN  7.220  7.233  7.255  7.253  7.261  7.258  ...  3.849
#
#       2016   2017   2018   2019   2020   2021   2022  2023  Unnamed: 68
# 261  1.658  1.649  1.605  1.546  1.529  1.522  1.510   NaN          NaN
# 262  4.214  4.112  4.043  3.963  3.886  3.795  3.716   NaN          NaN
# 263  2.261  2.334  2.418  2.475  2.401  2.374  2.341   NaN          NaN
# 264  4.707  4.614  4.536  4.451  4.379  4.308  4.242   NaN          NaN
# 265  3.771  3.706  3.659  3.599  3.545  3.491  3.437   NaN          NaN
#
# [5 rows x 69 columns]

# %%
df2.tail()
# Out:
#      Country Name Country Code                                 Indicator Name  \
# 261        Kosovo          XKX  GDP per capita, PPP (current international $)
# 262   Yemen, Rep.          YEM  GDP per capita, PPP (current international $)
# 263  South Africa          ZAF  GDP per capita, PPP (current international $)
# 264        Zambia          ZMB  GDP per capita, PPP (current international $)
# 265      Zimbabwe          ZWE  GDP per capita, PPP (current international $)
#
#         Indicator Code  1960  1961  1962  1963  1964  1965  ...          2015  \
# 261  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   8715.299803
# 262  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 263  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...  13600.616798
# 264  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   3368.460312
# 265  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   2692.290700
#
#              2016          2017          2018          2019          2020  \
# 261   9157.102974   9381.023878  10018.744283  10861.132103  10532.611375
# 262           NaN           NaN           NaN           NaN           NaN
# 263  13719.943192  13979.523875  13643.774139  13706.713816  13062.672773
# 264   3342.331991   3419.717835   3468.844121   3385.786570   3179.265411
# 265   2825.357165   2435.794358   2611.326409   2711.529334   2784.872395
#
#              2021          2022          2023  Unnamed: 68
# 261  12362.704808  13939.456503  15029.349098          NaN
# 262           NaN           NaN           NaN          NaN
# 263  14172.544251  15330.769274  15847.427560          NaN
# 264   3526.507418   3864.894367   4125.625556          NaN
# 265   3276.267753   3660.835501   3899.899233          NaN
#
# [5 rows x 69 columns]

# %%
# checking missing values
df1.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960               13
#                  ...
# 2020                7
# 2021                8
# 2022                8
# 2023              266
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
# checking missing values
df2.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              266
#                  ...
# 2020               20
# 2021               20
# 2022               24
# 2023               34
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
# Drop columns with missing data
df1 = df1.drop(columns=[str(year) for year in range(1960, 1990)] + ['2023'])
df2 = df2.drop(columns=[str(year) for year in range(1960, 1990)] + ['2023'])

# %%
df1.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                              Indicator Name  Indicator Code      1990  \
# 0  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  2.303000
# 1  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.166608
# 2  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  7.565000
# 3  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.518278
# 4  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  7
# ..            ...           ...           ...           ...           ...
# 261           NaN           NaN           NaN           NaN           NaN
# 262   2090.583472   2195.951770   2288.161048   2363.064868   2456.469319
# 263   6490.463267   6723.772430   6962.010411   7282.474521   7496.027146
# 264   1626.678510   1481.687403   1518.961422   1602.743971   1649.730832
# 265   1765.612818   1958.300190   1977.848035   2186.114786   2246.401152
#
#              1998  ...          2013          2014          2015  \
# 0    28743.827984  ...  36877.014132  36763.209005  37231.918495
# 1     2039.898635  ...   3337.142219   3473.843253   3502.296662
# 2             NaN  ...   2138.753060   2229.679539   2289.371986
# 3     1977.078638  ...   3971.199770   4180.427724   4130.736274
# 4     3210.303421  ...   7566.423051   7999.826851   7127.339573
# ..            ...  ...           ...           ...           ...
# 261           NaN  ...   8090.768293   8200.551108   8715.299803
# 262   2558.594835  ...   3437.429536           NaN           NaN
# 263   7523.949149  ...  13569.252848  13570.149711  13600.616798
# 264   1619.410350  ...   3514.718488   3475.759629   3368.460312
# 265   2299.553828  ...   2558.994062   2618.240859   2692.290700
#
#              2016          2017          2018          2019          2020  \
# 0    37444.441094  38697.949507  40379.293724  40124.757998  30437.202516
# 1     3595.841041   3640.628582   3695.386884   3783.518751   3666.871961
# 2     2217.296786   2338.778697   2436.006320   2589.410396   2568.341909
# 3     4072.792261   4139.387604   4272.387852   4525.091244   4503.396648
# 4     6850.384625   6998.796187   7353.349988   7533.511854   6455.119982
# ..            ...           ...           ...           ...           ...
# 261   9157.102974   9381.023878  10018.744283  10861.132103  10532.611375
# 262           NaN           NaN           NaN           NaN           NaN
# 263  13719.943192  13979.523875  13643.774139  13706.713816  13062.672773
# 264   3342.331991   3419.717835   3468.844121   3385.786570   3179.265411
# 265   2825.357165   2435.794358   2611.326409   2711.529334   2784.872395
#
#              2021          2022
# 0    38226.146157  45236.021214
# 1     3967.400629   4294.025281
# 2     2138.870247   2092.879952
# 3     4756.308419   5156.120103
# 4     7414.278958   7928.641498
# ..            ...           ...
# 261  12362.704808  13939.456503
# 262           NaN           NaN
# 263  14172.544251  15330.769274
# 264   3526.507418   3864.894367
# 265   3276.267753   3660.835501
#
# [266 rows x 34 columns]

# %%
df1_years = df1.loc[:, ['Country Name'] + [str(year) for year in range(1990, 2023)]]
df2_years = df2.loc[:, ['Country Name'] + [str(year) for year in range(1990, 2023)]]

# %%
##
df1.iloc[:, 1:] = df1.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
df2.iloc[:, 1:] = df2.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# %%
# Fill NaNs with the mean for each year column (ignoring "Country Name")
df1.iloc[:, 1:] = df1.iloc[:, 1:].apply(lambda x: x.fillna(x.mean()), axis=0)
df2.iloc[:, 1:] = df2.iloc[:, 1:].apply(lambda x: x.fillna(x.mean()), axis=0)
# Out:
# <ipython-input-99-d70e9bbb2eba>:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1.iloc[:, 1:] = df1.iloc[:, 1:].apply(lambda x: x.fillna(x.mean()), axis=0)
# <ipython-input-99-d70e9bbb2eba>:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.iloc[:, 1:] = df2.iloc[:, 1:].apply(lambda x: x.fillna(x.mean()), axis=0)

# %%
df1.isnull().sum()
# Out:
# Country Name        0
# Country Code      266
# Indicator Name    266
# Indicator Code    266
# 1990                0
# 1991                0
# 1992                0
# 1993                0
# 1994                0
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                
# 3   4139.387604   4272.387852   4525.091244   4503.396648   4756.308419
# 4   6998.796187   7353.349988   7533.511854   6455.119982   7414.278958
#
#            2022
# 0  45236.021214
# 1   4294.025281
# 2   2092.879952
# 3   5156.120103
# 4   7928.641498
#
# [5 rows x 37 columns]

# %%
## melting the 2 data frame
# converts  a DataFrame from a wide format (where each year is a separate column) to a long format (where each year becomes a row with associated values).

# %%
available_years = [str(year) for year in range(1990, 2023) if str(year) in df1.columns]

# %%
# Keep "Country Name" as the identifier
# Specify year columns to melt
# Name of the new column for years
# Name of the new column for values

melted_df1 = pd.melt(df1,id_vars=['Country Name'],value_vars= available_years,var_name='Year',value_name='Fertility Rate')

# %%
melted_df1.head()
# Out:
#                   Country Name  Year  Fertility Rate
# 0                        Aruba  1990        2.303000
# 1  Africa Eastern and Southern  1990        6.166608
# 2                  Afghanistan  1990        7.565000
# 3   Africa Western and Central  1990        6.518278
# 4                       Angola  1990        7.272000

# %%
melted_df2 = pd.melt(df2,id_vars=['Country Name'],value_vars=available_years,var_name='Year',value_name='GDP')

# %%
melted_df2.head()
# Out:
#                   Country Name  Year           GDP
# 0                        Aruba  1990  20754.231459
# 1  Africa Eastern and Southern  1990   1816.035866
# 2                  Afghanistan  1990   7824.873543
# 3   Africa Western and Central  1990   1741.687520
# 4                       Angola  1990   3283.471906

# %%
# Merged df1_melted and df2_melted on 'Country Name' and 'Year'
merged_df = pd.merge(melted_df1, melted_df2, on=['Country Name', 'Year'], how='outer', suffixes=('_df1', '_df2'))

# %%
merged_df.head()
# Out:
#   Country Name  Year  Fertility Rate          GDP
# 0  Afghanistan  1990           7.565  7824.873543
# 1  Afghanistan  1991           7.606  7991.905967
# 2  Afghanistan  1992           7.665  8187.915212
# 3  Afghanistan  1993           7.719  8414.439756
# 4  Afghanistan  1994           7.717  8700.178845

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=merged_df)
# Out:
# https://docs.google.com/spreadsheets/d/1-CHn_UCqH-Gju4GYVmWbfDDz_oJiPWTxtEoe8ndbj00#gid=0
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return frame.applymap(_clean_val).replace({np.nan: None})
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1-CHn_UCqH-Gju4GYVmWbfDDz_oJiPWTxtEoe8ndbj00#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# extracting 2013 data
df_2013 = merged_df[merged_df['Year'] == '2013']

# %%
df_2013.head()
# Out:
#                     Country Name  Year  Fertility Rate           GDP
# 23                   Afghanistan  2013         5.69600   2138.753060
# 56   Africa Eastern and Southern  2013         4.80882   3337.142219
# 89    Africa Western and Central  2013         5.50635   3971.199770
# 122                      Albania  2013         1.69700  10570.419833
# 155                      Algeria  2013         2.95700  14527.212323

# %%
numerical_columns = merged_df.select_dtypes(include=['float64', 'int64']).columns

# %%
correlation_matrix = merged_df[numerical_columns].corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title('Correlation Heatmap for Merged Data')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_2013, x='GDP', y='Fertility Rate', hue='Country Name', palette='tab20', legend=None)
# Out:
# <Axes: xlabel='GDP', ylabel='Fertility Rate'>
